# %%
import os
import pandas as pd
import numpy as np
import time
import sqlalchemy as db
import unidecode
from datetime import date
from dotenv import load_dotenv

# %% [markdown]
# # Download and inspect Dataset

# %%
# Load environment variables from .env file
load_dotenv()

# Access environment variable
geo_csv_local=os.environ['olist_geolocation_local']
geo_csv_azure=os.environ['olist_geolocation_azure']
customer_csv=os.environ['olist_customers_local']
seller_zip_csv=os.environ['olist_seller_zip_local']
db_local=os.environ['olist_db_local']
db_azure=os.environ['olist_db_azure']
export_path_local=os.environ['export_path_local']

# %%
# Download data from storage, convert to a dataframe
geo_df = pd.read_csv(geo_csv_local)
geo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
# Look at first 5 entries
geo_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
# Zip code prefix should be 5 digits long with leading zeroes
geo_df['geolocation_zip_code_prefix'] = geo_df['geolocation_zip_code_prefix'].apply(lambda x: '{0:0>5}'.format(x))

# %%
# Change lat/lng fields to strings to check for duplicates
geo_df['geolocation_lat'] = geo_df['geolocation_lat'].apply(str)
geo_df['geolocation_lng'] = geo_df['geolocation_lng'].apply(str)
geo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  object
#  1   geolocation_lat              1000163 non-null  object
#  2   geolocation_lng              1000163 non-null  object
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: object(5)
# memory usage: 38.2+ MB

# %%
# Count duplicates
num_dupes = geo_df.duplicated()
print(num_dupes.sum() / len(geo_df))
# Out:
# 0.2617883285024541

# %%
# Inspect unique values in city (1)
city = list(geo_df['geolocation_city'].unique())
print('Unique city values: ', geo_df['geolocation_city'].nunique(), '\n', city)
# Out:
# Unique city values:  8011
#  ['sao paulo', 'são paulo', 'sao bernardo do campo', 'jundiaí', 'taboão da serra', 'sãopaulo', 'sp', 'sa£o paulo', 'sao jose dos campos', 'osasco', 'carapicuíba', 'carapicuiba', 'barueri', 'santana de parnaiba', 'pirapora do bom jesus', 'santana de parnaíba', 'jandira', 'itapevi', 'cotia', 'taboao da serra', 'vargem grande paulista', 'embu das artes', 'itapecerica da serra', 'embu', 'são lourenço da serra', 'sao lourenco da serra', 'embu-guacu', 'embu-guaçu', 'embu guaçu', 'juquitiba', 'embu guacu', 'embuguacu', 'guarulhos', 'adamantina', 'guarulhos-sp', 'aruja', 'arujá', 'santa isabel', 'mairipora', 'mairiporã', 'cajamar', 'caieiras', 'jordanesia', 'polvilho', 'mauá', 'jordanésia', 'franco da rocha', 'francisco morato', 'poa', 'itaquaquecetuba', 'ferraz de vasconcelos', 'poá', 'suzano', 'mogi das cruzes', 'mogidascruzes', 'salesopolis', 'biritiba-mirim', 'guararema', 'salesópolis', 'biritiba mirim', 'santo andre', 'santo andré', 'maua', 'ribeirão pires', 'ribeirao pires', 'rio grande da serra', 'sao caetano do sul', 'são caetano do sul', 'são bernardo do campo', 'sbcampo', 'diadema', 'santos', 'bertioga', 'caruara', 'sao vicente', 'são vicente', 'guarujá', 'guaruja', 'cubatao', 'cubatão', 'sao sebastiao', 'ubatuba', 'ilhabela', 'caraguatatuba', 'são sebastião', 'maresias', 'sao francisco da praia', 'são francisco da praia', 'mongagua', 'praia grande', 'mongaguá', 'itanhaem', 'peruibe', 'itariri', 'pedro de toledo', 'itanhaém', 'peruíbe', 'ana dias', 'miracatu', 'juquia', 'juquiá', 'pariquera-acu', 'cajati', 'registro', 'jacupiranga', 'ilha comprida', 'barra do turvo', 'eldorado', 'iguape', 'cananéia', 'cananeia', 'sete barras', 'pariquera-açu', 'taubate', 'taubaté', 'natividade da serra', 'tremembe', 'lagoinha', 'tremembé', 'redencao da serra', 'catucaba', 'sao luiz do paraitinga', 'sao luis do paraitinga', 'são luiz do paraitinga', 'são josé dos campos', 'cacapava', 'paraibuna', 'caçapava', 'jambeiro', 'monteiro lobato', 'sao francisco xavier', 'são francisco xavier', 'jacarei', 'jacareí', 'santa branca', 'igarata', 'igaratá', 'pindamonhangaba', 'são bento do sapucaí', 'campos do jordao', 'sao bento do sapucai', 'santo antonio do pinhal', 'campos do jordão', 'santo antônio do pinhal', 'guaratingueta', 'potim', 'guaratinguetá', 'aparecida', 'cunha', 'roseira', 'campos de cunha', 'lorena', 'cachoeira paulista', 'piquete', 'silveiras', 'canas', 'cruzeiro', 'lavrinhas', 'arapeí', 'queluz', 'arapei', 'bananal', 'sao jose do barreiro', 'são josé do barreiro', 'areias', 'atibaia', 'braganca paulista', 'bom jesus dos perdoes', 'piracaia', 'bom jesus dos perdões', 'pedra bela', 'bragança paulista', 'joanopolis', 'vargem', 'nazaré paulista', 'nazare paulista', 'joanópolis', 'pinhalzinho', 'tuiuti', 'campinas', 'artur nogueira', 'hortolandia', 'paulinia', 'sumare', 'cosmopolis', 'monte mor', 'hortolândia', 'sumaré', 'cosmópolis', 'paulínia', 'engenheiro coelho', 'itatiba', 'vinhedo', 'jundiai', 'valinhos', 'varzea paulista', 'louveira', 'jarinu', 'campo limpo paulista', 'morungaba', 'itupeva', 'várzea paulista', 'indaiatuba', 'capivari', 'salto', 'itu', 'nova odessa', 'cabreuva', 'elias fausto', 'rafard', 'rio das pedras', 'jacare', 'cabreúva', 'mombuca', 'jacaré', 'jacaré (cabreúva)', 'cardeal', 'jacare (cabreuva)', 'bom fim do bom jesus', 'americana', 'limeira', 'piracicaba', "santa bárbara d'oeste", "santa barbara d'oeste", 'saltinho', 'cordeiropolis', 'iracemápolis', 'iracemapolis', 'santa barbara d oeste', 'cordeirópolis', 'santa bárbara doeste', 'santa barbara doeste', 'santa bárbara d`oeste', 'rio claro', 'sao carlos', 'ipeuna', 'santa gertrudes', 'itirapina', 'charqueada', 'são carlos', 'ribeirao bonito', 'ipeúna', 'sao pedro', 'são pedro', 'dourado', 'corumbataí', 'analandia', 'aguas de sao pedro', 'corumbatai', 'santa eudóxia', 'águas de são pedro', 'agua vermelha', 'ribeirão bonito', 'araras', 'pirassununga', 'porto ferreira', 'santa cruz das palmeiras', 'santa rita do passa quatro', 'leme', 'descalvado', 'santa cruz da conc ...

# %%
# Write function to replace special characters (portuguese orthography)
def replace_special_characters(df, column):
    df[column] = df[column].apply(unidecode.unidecode)
    return df

# %%
# Run function on merged_df
replace_special_characters(geo_df, 'geolocation_city')
# Out:
#         geolocation_zip_code_prefix      geolocation_lat     geolocation_lng  \
# 0                             01037   -23.54562128115268  -46.63929204800168
# 1                             01046   -23.54608112703553  -46.64482029837157
# 2                             01046   -23.54612896641469  -46.64295148361138
# 3                             01041    -23.5443921648681  -46.63949930627844
# 4                             01035  -23.541577961711493  -46.64160722329613
# ...                             ...                  ...                 ...
# 1000158                       99950   -28.06863887662893  -52.01070524698279
# 1000159                       99900   -27.87712511771236  -52.22488216264145
# 1000160                       99950   -28.07185541645192  -52.01471586864233
# 1000161                       99980   -28.38893187660049  -51.84687132274168
# 1000162                       99950   -28.07010363149126  -52.01865772856674
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# 1              sao paulo                SP
# 2              sao paulo                SP
# 3              sao paulo                SP
# 4              sao paulo                SP
# ...                  ...               ...
# 1000158         tapejara                RS
# 1000159   getulio vargas                RS
# 1000160         tapejara                RS
# 1000161  david canabarro                RS
# 1000162         tapejara                RS
#
# [1000163 rows x 5 columns]

# %%
# Count duplicates
num_dupes = geo_df.duplicated()
print(num_dupes.sum() / len(geo_df))
# Out:
# 0.27962142170826154

# %%
# Inspect unique values in city
city = list(geo_df['geolocation_city'].unique())
print('Unique city values: ', geo_df['geolocation_city'].nunique(), '\n', city)
# Out:
# Unique city values:  5969
#  ['sao paulo', 'sao bernardo do campo', 'jundiai', 'taboao da serra', 'saopaulo', 'sp', 'saPSo paulo', 'sao jose dos campos', 'osasco', 'carapicuiba', 'barueri', 'santana de parnaiba', 'pirapora do bom jesus', 'jandira', 'itapevi', 'cotia', 'vargem grande paulista', 'embu das artes', 'itapecerica da serra', 'embu', 'sao lourenco da serra', 'embu-guacu', 'embu guacu', 'juquitiba', 'embuguacu', 'guarulhos', 'adamantina', 'guarulhos-sp', 'aruja', 'santa isabel', 'mairipora', 'cajamar', 'caieiras', 'jordanesia', 'polvilho', 'maua', 'franco da rocha', 'francisco morato', 'poa', 'itaquaquecetuba', 'ferraz de vasconcelos', 'suzano', 'mogi das cruzes', 'mogidascruzes', 'salesopolis', 'biritiba-mirim', 'guararema', 'biritiba mirim', 'santo andre', 'ribeirao pires', 'rio grande da serra', 'sao caetano do sul', 'sbcampo', 'diadema', 'santos', 'bertioga', 'caruara', 'sao vicente', 'guaruja', 'cubatao', 'sao sebastiao', 'ubatuba', 'ilhabela', 'caraguatatuba', 'maresias', 'sao francisco da praia', 'mongagua', 'praia grande', 'itanhaem', 'peruibe', 'itariri', 'pedro de toledo', 'ana dias', 'miracatu', 'juquia', 'pariquera-acu', 'cajati', 'registro', 'jacupiranga', 'ilha comprida', 'barra do turvo', 'eldorado', 'iguape', 'cananeia', 'sete barras', 'taubate', 'natividade da serra', 'tremembe', 'lagoinha', 'redencao da serra', 'catucaba', 'sao luiz do paraitinga', 'sao luis do paraitinga', 'cacapava', 'paraibuna', 'jambeiro', 'monteiro lobato', 'sao francisco xavier', 'jacarei', 'santa branca', 'igarata', 'pindamonhangaba', 'sao bento do sapucai', 'campos do jordao', 'santo antonio do pinhal', 'guaratingueta', 'potim', 'aparecida', 'cunha', 'roseira', 'campos de cunha', 'lorena', 'cachoeira paulista', 'piquete', 'silveiras', 'canas', 'cruzeiro', 'lavrinhas', 'arapei', 'queluz', 'bananal', 'sao jose do barreiro', 'areias', 'atibaia', 'braganca paulista', 'bom jesus dos perdoes', 'piracaia', 'pedra bela', 'joanopolis', 'vargem', 'nazare paulista', 'pinhalzinho', 'tuiuti', 'campinas', 'artur nogueira', 'hortolandia', 'paulinia', 'sumare', 'cosmopolis', 'monte mor', 'engenheiro coelho', 'itatiba', 'vinhedo', 'valinhos', 'varzea paulista', 'louveira', 'jarinu', 'campo limpo paulista', 'morungaba', 'itupeva', 'indaiatuba', 'capivari', 'salto', 'itu', 'nova odessa', 'cabreuva', 'elias fausto', 'rafard', 'rio das pedras', 'jacare', 'mombuca', 'jacare (cabreuva)', 'cardeal', 'bom fim do bom jesus', 'americana', 'limeira', 'piracicaba', "santa barbara d'oeste", 'saltinho', 'cordeiropolis', 'iracemapolis', 'santa barbara d oeste', 'santa barbara doeste', 'santa barbara d`oeste', 'rio claro', 'sao carlos', 'ipeuna', 'santa gertrudes', 'itirapina', 'charqueada', 'ribeirao bonito', 'sao pedro', 'dourado', 'corumbatai', 'analandia', 'aguas de sao pedro', 'santa eudoxia', 'agua vermelha', 'araras', 'pirassununga', 'porto ferreira', 'santa cruz das palmeiras', 'santa rita do passa quatro', 'leme', 'descalvado', 'santa cruz da conceicao', 'mococa', 'sao jose do rio pardo', 'casa branca', 'caconde', 'tambau', 'tapiratiba', 'divinolandia', 'sao benedito das areias', 'itobi', 'sao sebastiao da grama', 'igarai', 'lagoa branca', 'venda branca', 'jaguariuna', 'vargem grande do sul', 'mogi-guacu', 'santo antonio de posse', 'mogi guacu', 'sao joao da boa vista', 'mogi mirim', 'holambra', 'aguai', 'conchal', 'estiva gerbi', 'mogi-mirim', 'aguas da prata', 'monte alegre do sul', 'martinho prado junior', 'sao roque da fartura', 'amparo', 'itapira', 'socorro', 'lindoia', 'aguas de lindoia', 'pedreira', 'serra negra', 'espirito santo do pinhal', 'barao ataliba nogueira', 'santo antonio do jardim', 'eleuterio', 'ribeirao preto', 'sertaozinho', 'serrana', 'pontal', 'cravinhos', 'bonfim paulista', 'guatapara', 'dumont', 'candia', 'cajuru', 'luis antonio', 'sao simao', 'santa rosa de viterbo', 'serra azul', 'cassia dos coqueiros', 'santa cruz da esperanca', 'santo antonio da alegria', 'brodowski', 'batatais', 'altinopolis', 'franca', 'jeriquara', 'rifaina', 'sao jose da bela vis ...

# %%
# Inspect duplicates to verify
num_dupes = geo_df.duplicated(keep=False)
display(geo_df[num_dupes].sort_values(['geolocation_lat', 'geolocation_lng']))
# Out:
#        geolocation_zip_code_prefix      geolocation_lat      geolocation_lng  \
# 774591                       68903   -0.002317920530416   -51.09144531474383
# 774648                       68903   -0.002317920530416   -51.09144531474383
# 774337                       68903  -0.0048387683330362  -51.091224003171845
# 774732                       68903  -0.0048387683330362  -51.091224003171845
# 775064                       68903  -0.0048387683330362  -51.091224003171845
# ...                            ...                  ...                  ...
# 769391                       68275    42.16725082536653   -6.898559051071016
# 769436                       68275    42.16725082536653   -6.898559051071016
# 769489                       68275    42.16725082536653   -6.898559051071016
# 860562                       83252    42.18400274298598   -8.723762147513938
# 860832                       83252    42.18400274298598   -8.723762147513938
#
#           geolocation_city geolocation_state
# 774591              macapa                AP
# 774648              macapa                AP
# 774337              macapa                AP
# 774732              macapa                AP
# 775064              macapa                AP
# ...                    ...               ...
# 769391     porto trombetas                PA
# 769436     porto trombetas                PA
# 769489     porto trombetas                PA
# 860562  ilha dos valadares                PR
# 860832  ilha dos valadares                PR
#
# [411211 rows x 5 columns]

# %%
# Drop duplicates
geo_df.drop_duplicates(inplace = True)
geo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720496 entries, 0 to 1000161
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   geolocation_zip_code_prefix  720496 non-null  object
#  1   geolocation_lat              720496 non-null  object
#  2   geolocation_lng              720496 non-null  object
#  3   geolocation_city             720496 non-null  object
#  4   geolocation_state            720496 non-null  object
# dtypes: object(5)
# memory usage: 33.0+ MB

# %% [markdown]
# # Check for dupes based on location info only

# %%
# Can 1 city have multiple zip code prefixes? Yes
# Can there be duplicate zip code prefixes? Yes
subset = ['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng']
loc_dupe = geo_df.duplicated(subset = subset, keep = False)
geo_df[loc_dupe].sort_values(by = 'geolocation_lat')
# Out:
#        geolocation_zip_code_prefix      geolocation_lat      geolocation_lng  \
# 813290                       76850   -10.78071026459307   -65.33175973540759
# 813631                       76850   -10.78071026459307   -65.33175973540759
# 815072                       76930   -11.33501778449655  -62.276737115089645
# 814616                       76930   -11.33501778449655  -62.276737115089645
# 815291                       76963  -11.421487424569468   -61.44937318799787
# ...                            ...                  ...                  ...
# 813109                       76868   -9.431109145449556   -61.99530666279655
# 813385                       76846   -9.655558978861762   -65.73848496097509
# 814075                       76846   -9.655558978861762   -65.73848496097509
# 779381                       69919   -9.958020162651277   -67.84582514698864
# 779069                       69919   -9.958020162651277   -67.84582514698864
#
#              geolocation_city geolocation_state
# 813290          guajara-mirim                RO
# 813631          guajara mirim                RO
# 815072      alvorada do oeste                RO
# 814616       alvorada d'oeste                RO
# 815291                 cacoal                RO
# ...                       ...               ...
# 813109     machadinho d oeste                RO
# 813385  vista alegre do abuna                RO
# 814075            porto velho                RO
# 779381            rio bracnco                AC
# 779069             rio branco                AC
#
# [684 rows x 5 columns]

# %%
# Remove dupes
geo_df = geo_df.drop_duplicates(subset = subset, keep = 'first').reset_index(drop = True)
geo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720154 entries, 0 to 720153
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   geolocation_zip_code_prefix  720154 non-null  object
#  1   geolocation_lat              720154 non-null  object
#  2   geolocation_lng              720154 non-null  object
#  3   geolocation_city             720154 non-null  object
#  4   geolocation_state            720154 non-null  object
# dtypes: object(5)
# memory usage: 27.5+ MB

# %%
display(geo_df.sort_values('geolocation_zip_code_prefix'))
# Out:
#        geolocation_zip_code_prefix      geolocation_lat      geolocation_lng  \
# 84                           01001   -23.54929199999999  -46.633559478233785
# 165                          01001  -23.550497706907517   -46.63433817805407
# 184                          01001   -23.55064182209015   -46.63440979032252
# 218                          01001   -23.54969829946912   -46.63390859285005
# 370                          01001  -23.550263371631395   -46.63419639384839
# ...                            ...                  ...                  ...
# 720105                       99980  -28.389731581235868   -51.85075455842014
# 719802                       99980   -28.38921783052984   -51.84601199170674
# 720153                       99980   -28.38893187660049   -51.84687132274168
# 719916                       99990  -28.329471980815523   -51.76910882440838
# 719818                       99990  -28.329717970441585   -51.76961468543976
#
#        geolocation_city geolocation_state
# 84            sao paulo                SP
# 165           sao paulo                SP
# 184           sao paulo                SP
# 218           sao paulo                SP
# 370           sao paulo                SP
# ...                 ...               ...
# 720105  david canabarro                RS
# 719802  david canabarro                RS
# 720153  david canabarro                RS
# 719916        muliterno                RS
# 719818        muliterno                RS
#
# [720154 rows x 5 columns]

# %%
# Inspect unique values in city (2)
print('Unique city values: ', geo_df['geolocation_city'].nunique())
# Out:
# Unique city values:  5957

# %% [markdown]
# # Use city_names from customer table

# %%
# Import customers database
cust_df = pd.read_csv(customer_csv)
cust_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
# Change field to string object to match geolocation table
cust_df['customer_zip_code_prefix'] = cust_df['customer_zip_code_prefix'].apply(str)

# %%
# Extract zip_code and city fields only
zip_df = cust_df[['customer_zip_code_prefix', 'customer_city']]

# %%
# Drop duplicates
zip = zip_df.drop_duplicates()

# %%
display(zip.sort_values('customer_zip_code_prefix'))
# Out:
#       customer_zip_code_prefix    customer_city
# 23914                     1003        sao paulo
# 11747                     1004        sao paulo
# 11378                     1005        sao paulo
# 20535                     1006        sao paulo
# 24302                     1007        sao paulo
# ...                        ...              ...
# 25169                    99960          charrua
# 17275                    99965       agua santa
# 41113                    99970          ciriaco
# 956                      99980  david canabarro
# 25752                    99990        muliterno
#
# [15034 rows x 2 columns]

# %%
# Merge geo_df with zip with a 'left join'
merged_df = geo_df.merge(zip, how='left', left_on='geolocation_zip_code_prefix', right_on='customer_zip_code_prefix')

# %%
# Replace geolocation_city with customer_city only if customer_city exists
merged_df['geolocation_city'] = merged_df['customer_city'].combine_first(merged_df['geolocation_city'])

# %%
# Remove customer columns
merged_df.drop(columns=['customer_city', 'customer_zip_code_prefix'], inplace=True)

# %%
# Inspect unique values in city
city = list(merged_df['geolocation_city'].unique())
print('Unique city values: ', merged_df['geolocation_city'].nunique(), '\n', city)
# Out:
# Unique city values:  5847
#  ['sao paulo', 'jundiai', 'taboao da serra', 'saopaulo', 'sp', 'sao jose dos campos', 'osasco', 'carapicuiba', 'barueri', 'santana de parnaiba', 'pirapora do bom jesus', 'jandira', 'itapevi', 'cotia', 'vargem grande paulista', 'embu das artes', 'itapecerica da serra', 'embu', 'sao lourenco da serra', 'embu-guacu', 'embu guacu', 'juquitiba', 'embuguacu', 'guarulhos', 'adamantina', 'guarulhos-sp', 'aruja', 'santa isabel', 'mairipora', 'cajamar', 'caieiras', 'jordanesia', 'polvilho', 'maua', 'franco da rocha', 'francisco morato', 'poa', 'itaquaquecetuba', 'ferraz de vasconcelos', 'suzano', 'mogi das cruzes', 'salesopolis', 'biritiba-mirim', 'guararema', 'biritiba mirim', 'santo andre', 'ribeirao pires', 'rio grande da serra', 'sao caetano do sul', 'sao bernardo do campo', 'sbcampo', 'diadema', 'santos', 'bertioga', 'caruara', 'sao vicente', 'guaruja', 'cubatao', 'sao sebastiao', 'ubatuba', 'ilhabela', 'caraguatatuba', 'maresias', 'mongagua', 'praia grande', 'itanhaem', 'peruibe', 'itariri', 'pedro de toledo', 'ana dias', 'miracatu', 'juquia', 'pariquera-acu', 'cajati', 'registro', 'jacupiranga', 'ilha comprida', 'barra do turvo', 'eldorado', 'iguape', 'cananeia', 'sete barras', 'taubate', 'natividade da serra', 'tremembe', 'lagoinha', 'redencao da serra', 'catucaba', 'sao luis do paraitinga', 'cacapava', 'paraibuna', 'jambeiro', 'monteiro lobato', 'sao francisco xavier', 'jacarei', 'santa branca', 'igarata', 'pindamonhangaba', 'sao bento do sapucai', 'campos do jordao', 'santo antonio do pinhal', 'guaratingueta', 'potim', 'aparecida', 'cunha', 'roseira', 'campos de cunha', 'lorena', 'cachoeira paulista', 'piquete', 'silveiras', 'canas', 'cruzeiro', 'lavrinhas', 'arapei', 'queluz', 'bananal', 'sao jose do barreiro', 'areias', 'atibaia', 'braganca paulista', 'bom jesus dos perdoes', 'piracaia', 'pedra bela', 'joanopolis', 'vargem', 'nazare paulista', 'pinhalzinho', 'tuiuti', 'campinas', 'artur nogueira', 'hortolandia', 'paulinia', 'sumare', 'cosmopolis', 'monte mor', 'engenheiro coelho', 'itatiba', 'vinhedo', 'valinhos', 'varzea paulista', 'louveira', 'jarinu', 'campo limpo paulista', 'morungaba', 'itupeva', 'indaiatuba', 'capivari', 'salto', 'itu', 'nova odessa', 'cabreuva', 'elias fausto', 'rafard', 'rio das pedras', 'jacare', 'mombuca', 'cardeal', 'bom fim do bom jesus', 'americana', 'limeira', 'piracicaba', "santa barbara d'oeste", 'santa barbara d oeste', 'saltinho', 'cordeiropolis', 'iracemapolis', 'rio claro', 'sao carlos', 'ipeuna', 'santa gertrudes', 'itirapina', 'charqueada', 'ribeirao bonito', 'sao pedro', 'dourado', 'corumbatai', 'analandia', 'aguas de sao pedro', 'santa eudoxia', 'ajapi', 'agua vermelha', 'araras', 'pirassununga', 'porto ferreira', 'santa cruz das palmeiras', 'santa rita do passa quatro', 'leme', 'descalvado', 'santa cruz da conceicao', 'mococa', 'sao jose do rio pardo', 'casa branca', 'caconde', 'tambau', 'tapiratiba', 'divinolandia', 'sao benedito das areias', 'itobi', 'sao sebastiao da grama', 'igarai', 'lagoa branca', 'venda branca', 'jaguariuna', 'monte alegre do sul', 'vargem grande do sul', 'mogi-guacu', 'santo antonio de posse', 'sao joao da boa vista', 'mogi mirim', 'holambra', 'aguai', 'conchal', 'mogi-mirim', 'estiva gerbi', 'aguas da prata', 'mogi guacu', 'sao roque da fartura', 'amparo', 'itapira', 'socorro', 'lindoia', 'aguas de lindoia', 'pedreira', 'serra negra', 'espirito santo do pinhal', 'barao ataliba nogueira', 'santo antonio do jardim', 'eleuterio', 'ribeirao preto', 'sertaozinho', 'serrana', 'pontal', 'cravinhos', 'bonfim paulista', 'guatapara', 'dumont', 'candia', 'cajuru', 'luis antonio', 'sao simao', 'santa rosa de viterbo', 'serra azul', 'cassia dos coqueiros', 'santa cruz da esperanca', 'santo antonio da alegria', 'brodowski', 'batatais', 'altinopolis', 'franca', 'jeriquara', 'rifaina', 'sao jose da bela vista', 'cristais paulista', 'patrocinio paulista', 'pedregulho', 'itirapua', 'ribeirao corrente', 'restinga', 'igarapava', 'ituverava', 'miguelopolis', 'aramina', 'buritiza ...

# %%
display(merged_df)
# Out:
#        geolocation_zip_code_prefix      geolocation_lat      geolocation_lng  \
# 0                            01037   -23.54562128115268   -46.63929204800168
# 1                            01046   -23.54608112703553   -46.64482029837157
# 2                            01046   -23.54612896641469   -46.64295148361138
# 3                            01041    -23.5443921648681   -46.63949930627844
# 4                            01035  -23.541577961711493   -46.64160722329613
# ...                            ...                  ...                  ...
# 722416                       99965  -28.180655165648112  -52.034366727397455
# 722417                       99950  -28.072187652217004   -52.01127167058397
# 722418                       99950  -28.068863628939333   -52.01296438020919
# 722419                       99950   -28.06863887662893   -52.01070524698279
# 722420                       99980   -28.38893187660049   -51.84687132274168
#
#        geolocation_city geolocation_state
# 0             sao paulo                SP
# 1             sao paulo                SP
# 2             sao paulo                SP
# 3             sao paulo                SP
# 4             sao paulo                SP
# ...                 ...               ...
# 722416       agua santa                RS
# 722417         tapejara                RS
# 722418         tapejara                RS
# 722419         tapejara                RS
# 722420  david canabarro                RS
#
# [722421 rows x 5 columns]

# %% [markdown]
#    # Use city name from seller table where not exist in customer table

# %%
# Import seller zip code file, prepped in pgadmin
seller_df = pd.read_csv(seller_zip_csv)
seller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_city             85 non-null     object
#  1   seller_zip_code_prefix  85 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.5+ KB

# %%
# Drop duplicates
seller_df = seller_df.drop_duplicates()
seller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_city             85 non-null     object
#  1   seller_zip_code_prefix  85 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.5+ KB

# %%
display(seller_df.sort_values('seller_zip_code_prefix'))
# Out:
#           seller_city  seller_zip_code_prefix
# 48          sao paulo                    1001
# 49          sao paulo                    1039
# 50          sao paulo                    1040
# 51          sao paulo                    1126
# 52          sao paulo                    1212
# ..                ...                     ...
# 10   cordilheira alta                   89819
# 34       porto alegre                   91901
# 13     estancia velha                   93608
# 4     bento goncalves                   95711
# 43  santa cruz do sul                   96816
#
# [85 rows x 2 columns]

# %%
# Change field to string object to match geolocation table
seller_df['seller_zip_code_prefix'] = seller_df['seller_zip_code_prefix'].apply(str)

# %%
# Merge merged_df with zip with a 'left join'
final_df = merged_df.merge(seller_df, how='left', left_on='geolocation_zip_code_prefix', right_on='seller_zip_code_prefix')

# %%
final_df.head()
# Out:
#   geolocation_zip_code_prefix      geolocation_lat     geolocation_lng  \
# 0                       01037   -23.54562128115268  -46.63929204800168
# 1                       01046   -23.54608112703553  -46.64482029837157
# 2                       01046   -23.54612896641469  -46.64295148361138
# 3                       01041    -23.5443921648681  -46.63949930627844
# 4                       01035  -23.541577961711493  -46.64160722329613
#
#   geolocation_city geolocation_state seller_city seller_zip_code_prefix
# 0        sao paulo                SP         NaN                    NaN
# 1        sao paulo                SP         NaN                    NaN
# 2        sao paulo                SP         NaN                    NaN
# 3        sao paulo                SP         NaN                    NaN
# 4        sao paulo                SP         NaN                    NaN

# %%
# Replace geolocation_city with seller_city only if seller_city exists
final_df['geolocation_city'] = final_df['seller_city'].combine_first(final_df['geolocation_city'])

# %%
# Remove customer columns
final_df.drop(columns=['seller_city', 'seller_zip_code_prefix'], inplace=True)

# %%
display(final_df)
# Out:
#        geolocation_zip_code_prefix      geolocation_lat      geolocation_lng  \
# 0                            01037   -23.54562128115268   -46.63929204800168
# 1                            01046   -23.54608112703553   -46.64482029837157
# 2                            01046   -23.54612896641469   -46.64295148361138
# 3                            01041    -23.5443921648681   -46.63949930627844
# 4                            01035  -23.541577961711493   -46.64160722329613
# ...                            ...                  ...                  ...
# 722449                       99965  -28.180655165648112  -52.034366727397455
# 722450                       99950  -28.072187652217004   -52.01127167058397
# 722451                       99950  -28.068863628939333   -52.01296438020919
# 722452                       99950   -28.06863887662893   -52.01070524698279
# 722453                       99980   -28.38893187660049   -51.84687132274168
#
#        geolocation_city geolocation_state
# 0             sao paulo                SP
# 1             sao paulo                SP
# 2             sao paulo                SP
# 3             sao paulo                SP
# 4             sao paulo                SP
# ...                 ...               ...
# 722449       agua santa                RS
# 722450         tapejara                RS
# 722451         tapejara                RS
# 722452         tapejara                RS
# 722453  david canabarro                RS
#
# [722454 rows x 5 columns]

# %% [markdown]
# # Look for dupes

# %%
# Count complete duplicates
num_dupes = final_df.duplicated()
num_dupes.sum()
# Out:
# 0

# %%
# Check for duplicates based on location info only
subset = ['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng']
loc_dupe = final_df.duplicated(subset = subset, keep = False)
final_df[loc_dupe].sort_values(by = 'geolocation_lat')
# Out:
#        geolocation_zip_code_prefix      geolocation_lat      geolocation_lng  \
# 506105                       55485  -10.895990269778954   -37.06039133666111
# 506104                       55485  -10.895990269778954   -37.06039133666111
# 491702                       48355  -11.716065903961772  -38.227774780029016
# 491701                       48355  -11.716065903961772  -38.227774780029016
# 491740                       48355  -11.720562650666556   -38.22460325413346
# ...                            ...                  ...                  ...
# 528769                       62600    -3.74011963481903    -39.5452731337601
# 506262                       55485   -8.040275033445656  -34.875009162122446
# 506261                       55485   -8.040275033445656  -34.875009162122446
# 506290                       55485   -8.760694500000003  -36.190030500000006
# 506289                       55485   -8.760694500000003  -36.190030500000006
#
#                    geolocation_city geolocation_state
# 506105  santo antonio das queimadas                PE
# 506104                       jurema                PE
# 491702                        apora                BA
# 491701                      itamira                BA
# 491740                        apora                BA
# ...                             ...               ...
# 528769                      itapaje                CE
# 506262  santo antonio das queimadas                PE
# 506261                       jurema                PE
# 506290  santo antonio das queimadas                PE
# 506289                       jurema                PE
#
# [4531 rows x 5 columns]

# %%
# Remove dupes
final_df = final_df.drop_duplicates(subset = subset, keep = 'first').reset_index(drop = True)
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720154 entries, 0 to 720153
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   geolocation_zip_code_prefix  720154 non-null  object
#  1   geolocation_lat              720154 non-null  object
#  2   geolocation_lng              720154 non-null  object
#  3   geolocation_city             720154 non-null  object
#  4   geolocation_state            720154 non-null  object
# dtypes: object(5)
# memory usage: 27.5+ MB

# %% [markdown]
# # Rename Cols to remove 'geolocation'

# %%
# Rename columns
final_df.rename(columns={'geolocation_zip_code_prefix': 'zip_code_prefix', 'geolocation_lat': 'lat', 'geolocation_lng': 'lng', 'geolocation_city': 'city', 'geolocation_state': 'state',}, inplace=True)
final_df.head()
# Out:
#   zip_code_prefix                  lat                 lng       city state
# 0           01037   -23.54562128115268  -46.63929204800168  sao paulo    SP
# 1           01046   -23.54608112703553  -46.64482029837157  sao paulo    SP
# 2           01046   -23.54612896641469  -46.64295148361138  sao paulo    SP
# 3           01041    -23.5443921648681  -46.63949930627844  sao paulo    SP
# 4           01035  -23.541577961711493  -46.64160722329613  sao paulo    SP

# %%
# Inspect unique values in city
city = final_df['city'].unique().tolist()
print('Unique city values: ', final_df['city'].nunique(), '\n', city)
# Out:
# Unique city values:  5831
#  ['sao paulo', 'jundiai', 'taboao da serra', 'saopaulo', 'sp', 'sao jose dos campos', 'osasco', 'carapicuiba', 'barueri', 'santana de parnaiba', 'pirapora do bom jesus', 'jandira', 'itapevi', 'cotia', 'vargem grande paulista', 'embu das artes', 'itapecerica da serra', 'embu', 'sao lourenco da serra', 'embu-guacu', 'embu guacu', 'juquitiba', 'embuguacu', 'guarulhos', 'adamantina', 'guarulhos-sp', 'aruja', 'santa isabel', 'mairipora', 'cajamar', 'caieiras', 'jordanesia', 'polvilho', 'maua', 'franco da rocha', 'francisco morato', 'poa', 'itaquaquecetuba', 'ferraz de vasconcelos', 'suzano', 'mogi das cruzes', 'salesopolis', 'biritiba-mirim', 'guararema', 'biritiba mirim', 'santo andre', 'ribeirao pires', 'rio grande da serra', 'sao caetano do sul', 'sao bernardo do campo', 'sbcampo', 'diadema', 'santos', 'bertioga', 'caruara', 'sao vicente', 'guaruja', 'cubatao', 'sao sebastiao', 'ubatuba', 'ilhabela', 'caraguatatuba', 'maresias', 'mongagua', 'praia grande', 'itanhaem', 'peruibe', 'itariri', 'pedro de toledo', 'ana dias', 'miracatu', 'juquia', 'pariquera-acu', 'cajati', 'registro', 'jacupiranga', 'ilha comprida', 'barra do turvo', 'eldorado', 'iguape', 'cananeia', 'sete barras', 'taubate', 'natividade da serra', 'tremembe', 'lagoinha', 'redencao da serra', 'catucaba', 'sao luis do paraitinga', 'cacapava', 'paraibuna', 'jambeiro', 'monteiro lobato', 'sao francisco xavier', 'jacarei', 'santa branca', 'igarata', 'pindamonhangaba', 'sao bento do sapucai', 'campos do jordao', 'santo antonio do pinhal', 'guaratingueta', 'potim', 'aparecida', 'cunha', 'roseira', 'campos de cunha', 'lorena', 'cachoeira paulista', 'piquete', 'silveiras', 'canas', 'cruzeiro', 'lavrinhas', 'arapei', 'queluz', 'bananal', 'sao jose do barreiro', 'areias', 'atibaia', 'braganca paulista', 'bom jesus dos perdoes', 'piracaia', 'pedra bela', 'joanopolis', 'vargem', 'nazare paulista', 'pinhalzinho', 'tuiuti', 'campinas', 'artur nogueira', 'hortolandia', 'paulinia', 'sumare', 'cosmopolis', 'monte mor', 'engenheiro coelho', 'itatiba', 'vinhedo', 'valinhos', 'varzea paulista', 'louveira', 'jarinu', 'campo limpo paulista', 'morungaba', 'itupeva', 'indaiatuba', 'capivari', 'salto', 'itu', 'nova odessa', 'cabreuva', 'elias fausto', 'rafard', 'rio das pedras', 'jacare', 'mombuca', 'cardeal', 'bom fim do bom jesus', 'americana', 'limeira', 'piracicaba', "santa barbara d'oeste", 'saltinho', 'cordeiropolis', 'iracemapolis', 'rio claro', 'sao carlos', 'ipeuna', 'santa gertrudes', 'itirapina', 'charqueada', 'ribeirao bonito', 'sao pedro', 'dourado', 'corumbatai', 'analandia', 'aguas de sao pedro', 'santa eudoxia', 'ajapi', 'agua vermelha', 'araras', 'pirassununga', 'porto ferreira', 'santa cruz das palmeiras', 'santa rita do passa quatro', 'leme', 'descalvado', 'santa cruz da conceicao', 'mococa', 'sao jose do rio pardo', 'casa branca', 'caconde', 'tambau', 'tapiratiba', 'divinolandia', 'sao benedito das areias', 'itobi', 'sao sebastiao da grama', 'igarai', 'lagoa branca', 'venda branca', 'jaguariuna', 'vargem grande do sul', 'mogi-guacu', 'santo antonio de posse', 'sao joao da boa vista', 'mogi mirim', 'holambra', 'aguai', 'conchal', 'estiva gerbi', 'mogi-mirim', 'aguas da prata', 'mogi guacu', 'sao roque da fartura', 'amparo', 'itapira', 'socorro', 'lindoia', 'aguas de lindoia', 'pedreira', 'serra negra', 'espirito santo do pinhal', 'barao ataliba nogueira', 'monte alegre do sul', 'santo antonio do jardim', 'eleuterio', 'ribeirao preto', 'sertaozinho', 'serrana', 'pontal', 'cravinhos', 'bonfim paulista', 'guatapara', 'dumont', 'candia', 'cajuru', 'luis antonio', 'sao simao', 'santa rosa de viterbo', 'serra azul', 'cassia dos coqueiros', 'santa cruz da esperanca', 'santo antonio da alegria', 'brodowski', 'batatais', 'altinopolis', 'franca', 'jeriquara', 'rifaina', 'sao jose da bela vista', 'cristais paulista', 'patrocinio paulista', 'pedregulho', 'itirapua', 'ribeirao corrente', 'restinga', 'igarapava', 'ituverava', 'miguelopolis', 'aramina', 'buritizal', 'guara', 'sao benedit ...

# %%
# Check for duplicates based on location info only
subset = ['lat', 'lng']
loc_dupe = final_df.duplicated(subset = subset, keep = False)
final_df[loc_dupe].sort_values(by = 'lat')
# Out:
#        zip_code_prefix                  lat                  lng      city  \
# 547948           68925  -0.0359277645283952   -51.16788044715518   santana
# 548052           68927  -0.0359277645283952   -51.16788044715518   santana
# 547904           68926  -0.0535231382433362   -51.16074622168749   santana
# 547805           68925  -0.0535231382433362   -51.16074622168749   santana
# 547631           68700  -1.2106477480160116   -47.17575463799356  capanema
# ...                ...                  ...                  ...       ...
# 548223           68903   0.0037175935876586   -51.06095157995029    macapa
# 548234           68904   0.0186163640328727  -51.087058404002775    macapa
# 548150           68902   0.0186163640328727  -51.087058404002775    macapa
# 548075           68906   0.0349717437610148  -51.062614502768845    macapa
# 548032           68900   0.0349717437610148  -51.062614502768845    macapa
#
#        state
# 547948    AP
# 548052    AP
# 547904    AP
# 547805    AP
# 547631    PA
# ...      ...
# 548223    AP
# 548234    AP
# 548150    AP
# 548075    AP
# 548032    AP
#
# [3308 rows x 5 columns]

# %%
# Final sort by zip_code_prefix and re-index
final_df.sort_values(['zip_code_prefix'], ignore_index=True, inplace=True)
final_df
# Out:
#        zip_code_prefix                  lat                  lng  \
# 0                01001   -23.54929199999999  -46.633559478233785
# 1                01001  -23.550497706907517   -46.63433817805407
# 2                01001   -23.55064182209015   -46.63440979032252
# 3                01001   -23.54969829946912   -46.63390859285005
# 4                01001  -23.550263371631395   -46.63419639384839
# ...                ...                  ...                  ...
# 720149           99980  -28.389731581235868   -51.85075455842014
# 720150           99980   -28.38921783052984   -51.84601199170674
# 720151           99980   -28.38893187660049   -51.84687132274168
# 720152           99990  -28.329471980815523   -51.76910882440838
# 720153           99990  -28.329717970441585   -51.76961468543976
#
#                    city state
# 0             sao paulo    SP
# 1             sao paulo    SP
# 2             sao paulo    SP
# 3             sao paulo    SP
# 4             sao paulo    SP
# ...                 ...   ...
# 720149  david canabarro    RS
# 720150  david canabarro    RS
# 720151  david canabarro    RS
# 720152        muliterno    RS
# 720153        muliterno    RS
#
# [720154 rows x 5 columns]

# %% [markdown]
# # Export to csv

# %%
# Export to .csv file
today = date.today()
final_df.to_csv(f'{export_path_local}geolocation_{today}.csv')
